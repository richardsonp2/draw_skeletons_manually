# %%
import skimage as ski
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load your image
image = cv2.imread('./image/im_M_PBS_4_8359_s8_Cell00005.png')

# Convert to grayscale (if needed)
#gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the image
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.show()

# %%
# Initialize a blank image with the same size as your input image
skeleton_image = np.zeros_like(image)

# %%
# Callback function to draw the skeleton
def draw_skeleton(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(skeleton_image, (x, y), 1, (255, 255, 255), -1)
    elif event == cv2.EVENT_MOUSEMOVE:
        if flags == cv2.EVENT_FLAG_LBUTTON:
            cv2.circle(skeleton_image, (x, y), 1, (255, 255, 255), -1)

# Display the image and set the callback function
cv2.namedWindow('Skeleton Drawing')
cv2.setMouseCallback('Skeleton Drawing', draw_skeleton)

while True:
    # Overlay the skeleton image on top of the original image
    overlay = cv2.addWeighted(image, 0.7, skeleton_image, 0.3, 0)

    cv2.imshow('Skeleton Drawing', overlay)
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):  # Press 'q' to quit and save
        break

    cv2.destroyAllWindows()

# Save the final skeleton image
cv2.imwrite('skeleton_image.png', skeleton_image)

# Optionally, display the final skeleton
import matplotlib.pyplot as plt
plt.imshow(skeleton_image, cmap='gray')
plt.title('Final Skeleton')
plt.show()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/peter/repos/draw_skeletons_manually/venv/lib/python3.12/site-packages/cv2/qt/plugins"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 15
#      11 cv2.setMouseCallback('Skeleton Drawing', draw_skeleton)
#      13 while True:
#      14     # Overlay the skeleton image on top of the original image
# ---> 15     overlay = cv2.addWeighted(image, 0.7, skeleton_image, 0.3, 0)
#      17     cv2.imshow('Skeleton Drawing', overlay)
#      18     key = cv2.waitKey(1) & 0xFF
#
# KeyboardInterrupt:

# %%
# save the final skeleton image as a binary image (0 or 255)
skeleton_image = cv2.cvtColor(skeleton_image, cv2.COLOR_BGR2GRAY)
cv2.imwrite('../masks/skeleton_image.png', skeleton_image)
# Out:
# False

# %%
shape = skeleton_image.shape

# Convert the image to a 224x224 image
skeleton_image_244 = cv2.resize(skeleton_image, (224, 224))

# %%
gui_skeleton_image_address = "./masks/im_M_PBS_4_8359_s8_Cell00005.png"
gui_skeleton_image = cv2.imread(gui_skeleton_image_address, cv2.IMREAD_GRAYSCALE)

# %%
gui_skeleton_image

# Show the type of the image
print("Image type: ", type(gui_skeleton_image))

# Show the pixel maximum value
print("Pixel maximum value: ", np.max(gui_skeleton_image))

# Show the pixel minimum value
print("Pixel minimum value: ", np.min(gui_skeleton_image))
# Out:
# Image type:  <class 'numpy.ndarray'>
# Pixel maximum value:  255
# Pixel minimum value:  0

# %%
gui_skeleton_image_244 = cv2.resize(gui_skeleton_image, (224, 224))
# Save the image
cv2.imwrite('./masks/skeleton_image_244.png', gui_skeleton_image_244)
# Out:
# True
